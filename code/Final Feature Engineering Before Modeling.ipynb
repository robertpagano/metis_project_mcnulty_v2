# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import pickle

# %matplotlib inline

# %%
with open('/Users/robertpagano/src/metis_project_mcnulty/data/interim_data/merged_data_cats_almost_ready.pickle', 'rb') as f:
    df = pickle.load(f)

# %%
pd.set_option('display.max_columns', None)

# %%
df.describe()
# Out:
#             is_male      is_fixed      dob_year     dob_month   intake_year  \
# count  32054.000000  32054.000000  32054.000000  32054.000000  32054.000000
# mean       0.444625      0.261340   2014.538622      6.136707   2015.810258
# std        0.496932      0.439372      3.034919      2.803705      1.495946
# min        0.000000      0.000000   1992.000000      1.000000   2013.000000
# 25%        0.000000      0.000000   2014.000000      4.000000   2015.000000
# 50%        0.000000      0.000000   2015.000000      6.000000   2016.000000
# 75%        1.000000      1.000000   2016.000000      8.000000   2017.000000
# max        1.000000      1.000000   2019.000000     12.000000   2019.000000
#
#        intake_month  intake_day_of_week  outcome_year  outcome_month  \
# count  32054.000000        32054.000000  32054.000000   32054.000000
# mean       6.873183            2.940694   2015.845324       7.107974
# std        2.950752            2.002341      1.501786       3.081659
# ...

# %%
df.head()
# Out:
#        animal_id         date_intake      intake_type intake_condition  \
# 110062   A664235 2013-10-01 08:33:00            Stray           Normal
# 76631    A664237 2013-10-01 08:33:00            Stray           Normal
# 66872    A664236 2013-10-01 08:33:00            Stray           Normal
# 96315    A664238 2013-10-01 09:33:00            Stray           Normal
# 117960   A664256 2013-10-01 10:59:00  Owner Surrender           Normal
#
#        sex_fixed_intake   age_raw               breed         color  \
# 110062          Unknown    1 week  domestic shorthair  orange/white
# 76631           Unknown    1 week  domestic shorthair  orange/white
# 66872           Unknown    1 week  domestic shorthair  orange/white
# 96315           Unknown  4 months  american shorthair   black/white
# 117960    Neutered Male  17 years  domestic shorthair  brown /white
#
#               date_outcome        dob outcome_type outcome_subtype  \
# ...

# %%
df['outcome_type'].unique()
# Out:
# array(['Transfer', 'Euthanasia', 'Adoption', 'Died', 'Return to Owner',
#        'Missing', 'Disposal', 'Rto-Adopt'], dtype=object)

# %% [markdown]
# Below I am filtering for just my target labels

# %%
df = df.loc[(df['outcome_type'] == 'Adoption') | (df['outcome_type'] == 'Transfer')]

# %%
df.head()
# Out:
#        animal_id         date_intake      intake_type intake_condition  \
# 110062   A664235 2013-10-01 08:33:00            Stray           Normal
# 76631    A664237 2013-10-01 08:33:00            Stray           Normal
# 66872    A664236 2013-10-01 08:33:00            Stray           Normal
# 117960   A664256 2013-10-01 10:59:00  Owner Surrender           Normal
# 113616   A664261 2013-10-01 11:21:00            Stray           Normal
#
#        sex_fixed_intake   age_raw               breed         color  \
# 110062          Unknown    1 week  domestic shorthair  orange/white
# 76631           Unknown    1 week  domestic shorthair  orange/white
# 66872           Unknown    1 week  domestic shorthair  orange/white
# 117960    Neutered Male  17 years  domestic shorthair  brown /white
# 113616    Intact Female   3 weeks  domestic shorthair
#
#               date_outcome        dob outcome_type outcome_subtype  \
# 110062 2013-10-01 10:39:00 2013-09-24     Transfer         Partner
# ...

# %%
df['intake_type'].unique()
# Out:
# array(['Stray', 'Owner Surrender', 'Public Assist', 'Euthanasia Request'],
#       dtype=object)

# %%
day_of_week={0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
df['weekday_intake'] = df['intake_day_of_week'].map(day_of_week)
df['weekday_outcome'] = df['outcome_day_of_week'].map(day_of_week)

# %%
df.head()
# Out:
#        animal_id         date_intake      intake_type intake_condition  \
# 110062   A664235 2013-10-01 08:33:00            Stray           Normal
# 76631    A664237 2013-10-01 08:33:00            Stray           Normal
# 66872    A664236 2013-10-01 08:33:00            Stray           Normal
# 117960   A664256 2013-10-01 10:59:00  Owner Surrender           Normal
# 113616   A664261 2013-10-01 11:21:00            Stray           Normal
#
#        sex_fixed_intake   age_raw               breed         color  \
# 110062          Unknown    1 week  domestic shorthair  orange/white
# 76631           Unknown    1 week  domestic shorthair  orange/white
# 66872           Unknown    1 week  domestic shorthair  orange/white
# 117960    Neutered Male  17 years  domestic shorthair  brown /white
# 113616    Intact Female   3 weeks  domestic shorthair
#
#               date_outcome        dob outcome_type outcome_subtype  \
# 110062 2013-10-01 10:39:00 2013-09-24     Transfer         Partner
# ...

# %%
df['is_weekend_intake'] = (df['intake_day_of_week'] >= 5).astype(int)
df.sample(10)
# Out:
#        animal_id         date_intake      intake_type intake_condition  \
# 30088    A760744 2017-10-23 11:56:00  Owner Surrender           Normal
# 33427    A754115 2017-07-15 16:16:00  Owner Surrender           Normal
# 61119    A761548 2017-11-06 16:24:00            Stray           Normal
# 28669    A704755 2015-06-08 16:51:00            Stray           Normal
# 96851    A694205 2014-12-22 14:06:00  Owner Surrender           Normal
# 1170     A352713 2017-04-13 16:29:00            Stray           Normal
# 68345    A708825 2015-08-01 12:06:00            Stray           Normal
# 102319   A711254 2015-09-04 13:00:00            Stray           Normal
# 113646   A708613 2015-07-29 16:00:00  Owner Surrender           Normal
# 19494    A777960 2018-08-06 12:31:00            Stray           Normal
#
#        sex_fixed_intake   age_raw                breed        color  \
# 30088     Neutered Male   3 years              persian  black/white
# ...

# %% [markdown]
# Below, going to try to have a cumaltive sum of intake for previous week. Here goes nothing:

# %%
df['count'] = 1

# %%
df = df.set_index(pd.DatetimeIndex(df['date_intake']))

# %%
df['intakes_last_week'] = df['count'].rolling('7d').sum()

# %%
df.sample(5)
# Out:
#                     animal_id         date_intake      intake_type  \
# date_intake
# 2015-08-21 16:13:00   A710333 2015-08-21 16:13:00            Stray
# 2016-09-17 12:02:00   A735031 2016-09-17 12:02:00            Stray
# 2015-02-16 11:58:00   A697002 2015-02-16 11:58:00  Owner Surrender
# 2015-05-08 16:09:00   A702062 2015-05-08 16:09:00            Stray
# 2016-04-08 16:44:00   A723913 2016-04-08 16:44:00            Stray
#
#                     intake_condition sex_fixed_intake  age_raw  \
# date_intake
# 2015-08-21 16:13:00           Normal    Intact Female  1 month
# 2016-09-17 12:02:00           Normal      Intact Male  4 weeks
# 2015-02-16 11:58:00           Normal    Intact Female   1 year
# 2015-05-08 16:09:00           Normal      Intact Male  2 years
# 2016-04-08 16:44:00           Normal    Intact Female  4 weeks
#
#                                   breed          color        date_outcome  \
# date_intake
# ...

# %%
df.columns
# Out:
# Index(['animal_id', 'date_intake', 'intake_type', 'intake_condition',
#        'sex_fixed_intake', 'age_raw', 'breed', 'color', 'date_outcome', 'dob',
#        'outcome_type', 'outcome_subtype', 'sex_fixed_outcome', 'is_male',
#        'is_fixed', 'dob_year', 'dob_month', 'intake_year', 'intake_month',
#        'intake_day_of_week', 'intake_time_of_day', 'outcome_year',
#        'outcome_month', 'outcome_day_of_week', 'outcome_time_of_day',
#        'date_only_intake', 'date_only_outcome', 'intake_temp', 'outcome_temp',
#        'intake_precip', 'outcome_precip', 'is_rain_intake', 'is_rain_outcome',
#        'stay_length', 'real_age_intake_days', 'cat_or_kitten', 'is_kitten',
#        'breed1', 'breed2', 'is_cfa_breed', 'is_domestic_breed', 'coat_pattern',
#        'color1', 'color2', 'coat', 'weekday_intake', 'weekday_outcome',
#        'is_weekend_intake', 'count', 'intakes_last_week'],
#       dtype='object')

# %% [markdown]
# Below creating specific df's for catboost, as it doesn't take pre-processed dummy variables

# %% [markdown]
# First setting month to actual month name

# %%
month_dict={1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

df['intake_month_name'] = df['intake_month'].map(month_dict)
df['outcome_month_name'] = df['outcome_month'].map(month_dict)

# %% [markdown]
# Now need to set breed to either "CFA" or "domestic"

# %%
cfa_breeds = ['Abyssinian', 'American Bobtail', 'American Curl', 'American Shorthair', 'American Wirehair', 
              'Balinese', 'Bengal', 'Birman', 'Bombay', 'British Shorthair', 'Burmese', 'Burmilla', 
              'Chartreux', 'Colorpoint Shorthair', 'Cornish Rex', 'Devon Rex', 'Egyptian Mau', 'European Burmese', 
              'Exotic', 'Havana Brown', 'Japanese Bobtail', 'Korat', 'LaPerm', 'Maine Coon', 'Manx', 
              'Norwegian Forest Cat', 'Ocicat', 'Oriental', 'Persian', 'Ragamuffin', 'Ragdoll', 'Russian Blue', 
              'Scottish Fold', 'Selkirk Rex', 'Siamese', 'Siberian', 'Singapura', 'Somali', 'Tonkinese', 
              'Turkish Angora', 'Turkish Van']

cfa_breeds = [i.lower() for i in cfa_breeds]
cfa_breeds = '|'.join(cfa_breeds)

# %%
df['breed_type'] = np.where((df['breed1'].str.contains(cfa_breeds)) | 
                                (df['breed2'].str.contains(cfa_breeds)), 
                                'CFA Breed', 'Domestic Breed')

# %% [markdown]
# And finally creating the df's with this info:

# %%
df_X_catboost_all = df.loc[:, ['outcome_type', 
                              'intake_type',
                              'intake_condition',
                              'sex_fixed_intake',
                              'intake_month_name',
                              'weekday_intake', 
                              'outcome_month_name', 
                              'weekday_outcome',
                              'intake_temp',
                              'outcome_temp', 
                              'intake_precip',
                              'outcome_precip',
                              'stay_length',
                              'real_age_intake_days',
                              'cat_or_kitten',
                              'breed_type',
                              'intakes_last_week']]

# %%
df_X_catboost_intake_only = df.loc[:, ['outcome_type', 
                              'intake_type',
                              'intake_condition',
                              'sex_fixed_intake',
                              'intake_month_name',
                              'weekday_intake',  
                              'intake_temp', 
                              'intake_precip',
                              'real_age_intake_days',
                              'cat_or_kitten',
                              'breed_type',
                              'intakes_last_week']]

# %%
df_X_catboost_outcome_only = df.loc[:, ['outcome_type', 
                              'intake_type',
                              'intake_condition',
                              'sex_fixed_intake', 
                              'outcome_month_name', 
                              'weekday_outcome',
                              'outcome_temp', 
                              'outcome_precip',
                              'stay_length',
                              'real_age_intake_days',
                              'cat_or_kitten',
                              'breed_type']]

# %%
df.head()
# Out:
#                     animal_id         date_intake      intake_type  \
# date_intake
# 2013-10-01 08:33:00   A664235 2013-10-01 08:33:00            Stray
# 2013-10-01 08:33:00   A664237 2013-10-01 08:33:00            Stray
# 2013-10-01 08:33:00   A664236 2013-10-01 08:33:00            Stray
# 2013-10-01 10:59:00   A664256 2013-10-01 10:59:00  Owner Surrender
# 2013-10-01 11:21:00   A664261 2013-10-01 11:21:00            Stray
#
#                     intake_condition sex_fixed_intake   age_raw  \
# date_intake
# 2013-10-01 08:33:00           Normal          Unknown    1 week
# 2013-10-01 08:33:00           Normal          Unknown    1 week
# 2013-10-01 08:33:00           Normal          Unknown    1 week
# 2013-10-01 10:59:00           Normal    Neutered Male  17 years
# 2013-10-01 11:21:00           Normal    Intact Female   3 weeks
#
#                                   breed         color        date_outcome  \
# date_intake
# ...

# %%
df_dummies = pd.get_dummies(df, columns=['intake_type', 'intake_condition', 'outcome_type', 'intake_year', 'outcome_year', 'weekday_intake', 'weekday_outcome', 'intake_month', 'outcome_month'])

# %%
df_dummies_drop_one = pd.get_dummies(df, columns=['intake_type', 'intake_condition', 'outcome_type', 'intake_year', 'outcome_year', 'weekday_intake', 'weekday_outcome', 'intake_month', 'outcome_month'], drop_first=True)

# %%
df_X_all_features = df_dummies.loc[:, ['outcome_type_Transfer',
                                       'intakes_last_week',
                                       'is_male', 
                                       'is_fixed', 
                                       'intake_temp', 
                                       'outcome_temp', 
                                       'is_rain_intake', 
                                       'is_rain_outcome', 
                                       'stay_length', 
                                       'real_age_intake_days', 
                                       'is_kitten', 
                                       'is_cfa_breed', 
                                       'is_domestic_breed',
                                       'is_weekend_intake',
                                       'intake_type_Euthanasia Request',
                                       'intake_type_Owner Surrender', 
                                       'intake_type_Stray',
                                       'intake_type_Public Assist',
                                       'intake_condition_Normal', 
                                       'intake_condition_Nursing', 
                                       'intake_condition_Injured', 
                                       'intake_condition_Sick',
                                       'intake_condition_Aged',
                                       'intake_condition_Feral',
                                       'intake_condition_Other',
                                       'intake_condition_Pregnant',
                                       'weekday_intake_Friday',
                                       'weekday_intake_Monday',
                                       'weekday_intake_Saturday',
                                       'weekday_intake_Sunday',
                                       'weekday_intake_Thursday',
                                       'weekday_intake_Tuesday',
                                       'weekday_intake_Wednesday',
                                       'weekday_outcome_Friday',
                                       'weekday_outcome_Monday',
                                       'weekday_outcome_Saturday',
                                       'weekday_outcome_Sunday',
                                       'weekday_outcome_Thursday',
                                       'weekday_outcome_Tuesday',
                                       'weekday_outcome_Wednesday',
                                       'intake_month_1',
                                       'intake_month_2',
                                       'intake_month_3',
                                       'intake_month_4',
                                       'intake_month_5',
                                       'intake_month_6',
                                       'intake_month_7',
                                       'intake_month_8',
                                       'intake_month_9',
                                       'intake_month_10',
                                       'intake_month_11',
                                       'intake_month_12',
                                       'outcome_month_1',
                                       'outcome_month_2',
                                       'outcome_month_3',
                                       'outcome_month_4',
                                       'outcome_month_5',
                                       'outcome_month_6',
                                       'outcome_month_7',
                                       'outcome_month_8',
                                       'outcome_month_9',
                                       'outcome_month_10',
                                       'outcome_month_11',
                                       'outcome_month_12']]

# %%
df_X_all_features_drop_one = df_dummies_drop_one.loc[:, ['outcome_type_Transfer', 
                                       'intakes_last_week',
                                       'is_male', 
                                       'is_fixed', 
                                       'intake_temp', 
                                       'outcome_temp', 
                                       'is_rain_intake', 
                                       'is_rain_outcome', 
                                       'stay_length', 
                                       'real_age_intake_days', 
                                       'is_kitten', 
                                       'is_cfa_breed', 
                                       'is_weekend_intake',
                                       'intake_type_Owner Surrender', 
                                       'intake_type_Stray',
                                       'intake_type_Public Assist',
                                       'intake_condition_Normal', 
                                       'intake_condition_Nursing', 
                                       'intake_condition_Injured', 
                                       'intake_condition_Sick',
                                       'intake_condition_Feral',
                                       'intake_condition_Other',
                                       'intake_condition_Pregnant',
                                       'weekday_intake_Monday',
                                       'weekday_intake_Saturday',
                                       'weekday_intake_Sunday',
                                       'weekday_intake_Thursday',
                                       'weekday_intake_Tuesday',
                                       'weekday_intake_Wednesday',
                                       'weekday_outcome_Monday',
                                       'weekday_outcome_Saturday',
                                       'weekday_outcome_Sunday',
                                       'weekday_outcome_Thursday',
                                       'weekday_outcome_Tuesday',
                                       'weekday_outcome_Wednesday',
                                       'intake_month_2',
                                       'intake_month_3',
                                       'intake_month_4',
                                       'intake_month_5',
                                       'intake_month_6',
                                       'intake_month_7',
                                       'intake_month_8',
                                       'intake_month_9',
                                       'intake_month_10',
                                       'intake_month_11',
                                       'intake_month_12',
                                       'outcome_month_2',
                                       'outcome_month_3',
                                       'outcome_month_4',
                                       'outcome_month_5',
                                       'outcome_month_6',
                                       'outcome_month_7',
                                       'outcome_month_8',
                                       'outcome_month_9',
                                       'outcome_month_10',
                                       'outcome_month_11',
                                       'outcome_month_12']]

# %%
df_X_intake_only = df_dummies.loc[:, ['outcome_type_Transfer',
                                      'intakes_last_week',
                                       'is_male', 
                                       'is_fixed', 
                                       'intake_temp', 
                                       'is_rain_intake',  
                                       'real_age_intake_days', 
                                       'is_kitten', 
                                       'is_cfa_breed', 
                                       'is_domestic_breed',
                                       'is_weekend_intake',
                                       'intake_type_Euthanasia Request',
                                       'intake_type_Owner Surrender', 
                                       'intake_type_Stray',
                                       'intake_type_Public Assist',
                                       'intake_condition_Normal', 
                                       'intake_condition_Nursing', 
                                       'intake_condition_Injured', 
                                       'intake_condition_Sick',
                                       'intake_condition_Aged',
                                       'intake_condition_Feral',
                                       'intake_condition_Other',
                                       'intake_condition_Pregnant',
                                       'weekday_intake_Friday',
                                       'weekday_intake_Monday',
                                       'weekday_intake_Saturday',
                                       'weekday_intake_Sunday',
                                       'weekday_intake_Thursday',
                                       'weekday_intake_Tuesday',
                                       'weekday_intake_Wednesday',
                                       'intake_month_1',
                                       'intake_month_2',
                                       'intake_month_3',
                                       'intake_month_4',
                                       'intake_month_5',
                                       'intake_month_6',
                                       'intake_month_7',
                                       'intake_month_8',
                                       'intake_month_9',
                                       'intake_month_10',
                                       'intake_month_11',
                                       'intake_month_12',]]

# %%
df_X_all_intake_drop_one = df_dummies_drop_one.loc[:, ['outcome_type_Transfer', 
                                       'is_male',
                                       'intakes_last_week',
                                       'is_fixed', 
                                       'intake_temp', 
                                       'is_rain_intake',   
                                       'real_age_intake_days', 
                                       'is_kitten', 
                                       'is_cfa_breed', 
                                       'is_weekend_intake',
                                       'intake_type_Owner Surrender', 
                                       'intake_type_Stray',
                                       'intake_type_Public Assist',
                                       'intake_condition_Normal', 
                                       'intake_condition_Nursing', 
                                       'intake_condition_Injured', 
                                       'intake_condition_Sick',
                                       'intake_condition_Feral',
                                       'intake_condition_Other',
                                       'intake_condition_Pregnant',
                                       'weekday_intake_Monday',
                                       'weekday_intake_Saturday',
                                       'weekday_intake_Sunday',
                                       'weekday_intake_Thursday',
                                       'weekday_intake_Tuesday',
                                       'weekday_intake_Wednesday',
                                       'intake_month_2',
                                       'intake_month_3',
                                       'intake_month_4',
                                       'intake_month_5',
                                       'intake_month_6',
                                       'intake_month_7',
                                       'intake_month_8',
                                       'intake_month_9',
                                       'intake_month_10',
                                       'intake_month_11',
                                       'intake_month_12',]]

# %%
df_X_all_features.head()
# Out:
#                      outcome_type_Transfer  intakes_last_week  is_male  \
# date_intake
# 2013-10-01 08:33:00                      1                1.0        0
# 2013-10-01 08:33:00                      1                2.0        0
# 2013-10-01 08:33:00                      1                3.0        0
# 2013-10-01 10:59:00                      1                4.0        1
# 2013-10-01 11:21:00                      1                5.0        0
#
#                      is_fixed  intake_temp  outcome_temp  is_rain_intake  \
# date_intake
# 2013-10-01 08:33:00         1         75.4          75.4               0
# 2013-10-01 08:33:00         1         75.4          75.4               0
# 2013-10-01 08:33:00         1         75.4          75.4               0
# 2013-10-01 10:59:00         1         75.4          70.4               0
# 2013-10-01 11:21:00         0         75.4          75.4               0
#
# ...

# %%
df_X_outcome_only = df_dummies.loc[:, ['outcome_type_Transfer',
                                       'intakes_last_week',
                                       'is_male', 
                                       'is_fixed',  
                                       'outcome_temp',  
                                       'is_rain_outcome', 
                                       'stay_length', 
                                       'real_age_intake_days', 
                                       'is_kitten', 
                                       'is_cfa_breed', 
                                       'is_domestic_breed',
                                       'weekday_outcome_Friday',
                                       'weekday_outcome_Monday',
                                       'weekday_outcome_Saturday',
                                       'weekday_outcome_Sunday',
                                       'weekday_outcome_Thursday',
                                       'weekday_outcome_Tuesday',
                                       'weekday_outcome_Wednesday',
                                       'outcome_month_1',
                                       'outcome_month_2',
                                       'outcome_month_3',
                                       'outcome_month_4',
                                       'outcome_month_5',
                                       'outcome_month_6',
                                       'outcome_month_7',
                                       'outcome_month_8',
                                       'outcome_month_9',
                                       'outcome_month_10',
                                       'outcome_month_11',
                                       'outcome_month_12']]

# %%
df_X_outcome_only_drop_one = df_dummies_drop_one.loc[:, ['outcome_type_Transfer', 
                                       'intakes_last_week',
                                       'is_male', 
                                       'is_fixed',  
                                       'outcome_temp', 
                                       'is_rain_outcome', 
                                       'stay_length', 
                                       'real_age_intake_days', 
                                       'is_kitten', 
                                       'is_cfa_breed', 
                                       'weekday_outcome_Monday',
                                       'weekday_outcome_Saturday',
                                       'weekday_outcome_Sunday',
                                       'weekday_outcome_Thursday',
                                       'weekday_outcome_Tuesday',
                                       'weekday_outcome_Wednesday',
                                       'outcome_month_2',
                                       'outcome_month_3',
                                       'outcome_month_4',
                                       'outcome_month_5',
                                       'outcome_month_6',
                                       'outcome_month_7',
                                       'outcome_month_8',
                                       'outcome_month_9',
                                       'outcome_month_10',
                                       'outcome_month_11',
                                       'outcome_month_12']]

# %%
#pickling all features with no dropped dummies

with open('/Users/robertpagano/src/metis_project_mcnulty/data/final_for_modeling/final_features_all.pickle', 'wb') as to_write:
    pickle.dump(df_X_all_features, to_write)

# %%
#pickling all features with dropped first dummy for logistic regression

with open('/Users/robertpagano/src/metis_project_mcnulty/data/final_for_modeling/final_features_all_drop_one.pickle', 'wb') as to_write:
    pickle.dump(df_X_all_features_drop_one, to_write)

# %%
#pickling all INTAKE ONLY features with no dropped dummies. For predictions only on intake data

with open('/Users/robertpagano/src/metis_project_mcnulty/data/final_for_modeling/final_features_intake_only.pickle', 'wb') as to_write:
    pickle.dump(df_X_intake_only, to_write)

# %%
#pickling all INTAKE ONLY features with one dropped dummies. For predictions only on intake data

with open('/Users/robertpagano/src/metis_project_mcnulty/data/final_for_modeling/final_features_intake_only_drop_one.pickle', 'wb') as to_write:
    pickle.dump(df_X_all_intake_drop_one, to_write)

# %%
#pickling all OUTCOME ONLY features with no dropped dummies. For predictions only on outcome data

with open('/Users/robertpagano/src/metis_project_mcnulty/data/final_for_modeling/final_features_outcome_only.pickle', 'wb') as to_write:
    pickle.dump(df_X_outcome_only, to_write)

# %%
#pickling all OUTCOME ONLY features with one dropped dummies. For predictions only on outcome data

with open('/Users/robertpagano/src/metis_project_mcnulty/data/final_for_modeling/final_features_outcome_only_drop_one.pickle', 'wb') as to_write:
    pickle.dump(df_X_outcome_only_drop_one, to_write)

# %%
#pickling all features with no dummies for catboost

with open('/Users/robertpagano/src/metis_project_mcnulty/data/final_for_modeling/final_features_catboost.pickle', 'wb') as to_write:
    pickle.dump(df_X_catboost_all, to_write)

# %%
#pickling intake features with no dummies for catboost

with open('/Users/robertpagano/src/metis_project_mcnulty/data/final_for_modeling/final_features_catboost_intake.pickle', 'wb') as to_write:
    pickle.dump(df_X_catboost_intake_only, to_write)

# %%
#pickling outcome features with no dummies for catboost

with open('/Users/robertpagano/src/metis_project_mcnulty/data/final_for_modeling/final_features_catboost_outcome.pickle', 'wb') as to_write:
    pickle.dump(df_X_catboost_outcome_only, to_write)

# %%
#Sending df to csv for EDA in Tablaeu
df.to_csv('/Users/robertpagano/src/metis_project_mcnulty/data/interim_data/df.csv')
