# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('~/src/Project_3_RAW_DATA/201812-citibike-tripdata.csv')
df.head()
# Out:
#    over 30  over 45  tripduration starttime stoptime  start station id  \
# 0    False    False           689   00:04.3  11:33.8            3359.0
# 1    False    False           204   00:05.5  03:30.5            3504.0
# 2    False    False           316   00:10.2  05:27.2             270.0
# 3    False    False           499   24:33.5  32:52.7            3117.0
# 4    False    False           334   24:31.1  30:05.5            3140.0
#
#          start station name  start station latitude  start station longitude  \
# 0     E 68 St & Madison Ave               40.769157               -73.967035
# 1  E 123 St & Lexington Ave               40.802926               -73.937900
# 2   Adelphi St & Myrtle Ave               40.693083               -73.971789
# 3   Franklin St & Dupont St               40.735640               -73.958660
# 4           1 Ave & E 78 St               40.771404               -73.953517
#
#    end station id         end station name  end station latitude  \
# ...

# %%
df['over_time'] = df[df['over 30', 'over 45'].any(1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('over 30', 'over 45')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-f2c62e9a687f> in <module>
# ...
